# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_excel('http://taanila.fi/titanic.xlsx')
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
df1 = pd.crosstab(df['pclass'], df['survived'], normalize='columns')
df1.columns = ['Ei selvinnyt', 'Selvisi']
(df1*100).style.format('{:.1f} %')
# Out:
# <style  type="text/css" >
# </style><table id="T_6b2c8892_0545_11ea_b1ae_1062e5007e39" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Ei selvinnyt</th>        <th class="col_heading level0 col1" >Selvisi</th>    </tr>    <tr>        <th class="index_name level0" >pclass</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6b2c8892_0545_11ea_b1ae_1062e5007e39level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_6b2c8892_0545_11ea_b1ae_1062e5007e39row0_col0" class="data row0 col0" >15.2 %</td>
#                         <td id="T_6b2c8892_0545_11ea_b1ae_1062e5007e39row0_col1" class="data row0 col1" >40.0 %</td>
#             </tr>
#             <tr>
#                         <th id="T_6b2c8892_0545_11ea_b1ae_1062e5007e39level0_row1" class="row_heading level0 row1" >2</th>
# ...

# %%
ax1 = df['age'].hist(bins=6)
ax1.set_xlabel('Ikä')
ax1.set_ylabel('Lukumäärä')
plt.savefig('histogrammi.png', bbox_inches='tight')

# %%
df['home.dest'] = df['home.dest'].astype(str)
df[df['home.dest'].str.contains('Finland')]
# Out:
#       pclass  survived                                               name  \
# 375        2         0                         Collander, Mr. Erik Gustaf
# 445        2         0                              Hiltunen, Miss. Marta
# 558        2         1                      Silven, Miss. Lyyli Karoliina
# 560        2         1                              Sinkkonen, Miss. Anna
# 606        3         1           Abrahamsson, Mr. Abraham August Johannes
# 615        3         0                        Alhomaki, Mr. Ilmari Rudolf
# 625        3         1                    Andersson, Miss. Erna Alexandra
# 655        3         0                         Backstrom, Mr. Karl Alfred
# 656        3         1  Backstrom, Mrs. Karl Alfred (Maria Mathilda Gu...
# 671        3         0                       Berglund, Mr. Karl Ivar Sven
# 837        3         0                     Gustafsson, Mr. Anders Vilhelm
# 838        3         0                       Gustafsson, Mr. Johan Birger
# ...
