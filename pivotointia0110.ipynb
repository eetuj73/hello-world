# %%
import pandas as pd
import matplotlib.pyplot as plt
import sqlite3
# %matplotlib inline

# %%
conn = sqlite3.connect('Northwind_large.sqlite')
cur = conn.cursor()

# %%
cur.execute("SELECT name FROM sqlite_master WHERE type='table'")
print(cur.fetchall())
# Out:
# [('Employees',), ('Categories',), ('Customers',), ('Shippers',), ('Suppliers',), ('Orders',), ('Products',), ('OrderDetails',), ('CustomerCustomerDemo',), ('CustomerDemographics',), ('Region',), ('Territories',), ('EmployeeTerritories',)]

# %%
df = pd.read_sql_query("""SELECT Orders.OrderDate, Products.ProductName, Categories.CategoryName, 
    OrderDetails.UnitPrice, OrderDetails.Quantity, OrderDetails.Discount, Customers.CompanyName,
    Orders.ShipCountry, Orders.ShipRegion, Orders.ShipVia, Employees.LastName  
    FROM OrderDetails 
    JOIN Orders ON Orders.Id=OrderDetails.OrderId
    JOIN Employees ON Employees.Id=Orders.EmployeeId
    JOIN Customers ON Customers.Id=Orders.CustomerId
    JOIN Products ON Products.Id=OrderDetails.ProductId
    JOIN Categories ON Products.CategoryId=Categories.Id""", conn)

df.shape
# Out:
# (621806, 11)

# %%
df.tail()
# Out:
#                   OrderDate                       ProductName    CategoryName  \
# 621801  2013-08-31 02:59:28               Gustaf's Knäckebröd  Grains/Cereals
# 621802  2013-08-31 02:59:28   Original Frankfurter grüne Soße      Condiments
# 621803  2013-08-31 02:59:28                      Alice Mutton    Meat/Poultry
# 621804  2013-08-31 02:59:28      Grandma's Boysenberry Spread      Condiments
# 621805  2013-08-31 02:59:28  Louisiana Fiery Hot Pepper Sauce      Condiments
#
#         UnitPrice  Quantity  Discount                         CompanyName  \
# 621801      21.00        20       0.0  Ana Trujillo Emparedados y helados
# 621802      13.00        11       0.0  Ana Trujillo Emparedados y helados
# 621803      39.00        45       0.0  Ana Trujillo Emparedados y helados
# 621804      25.00         7       0.0  Ana Trujillo Emparedados y helados
# 621805      21.05        27       0.0  Ana Trujillo Emparedados y helados
#
#        ShipCountry     ShipRegion  ShipVia LastName
# 621801   Venezuela  South America        3  Davolio
# 621802   Venezuela  South America        3  Davolio
# 621803   Venezuela  South America        3  Davolio
# 621804   Venezuela  South America        3  Davolio
# 621805   Venezuela  South America        3  Davolio

# %%
df.index = pd.to_datetime(df['OrderDate'])
df = df.drop('OrderDate', axis=1)
df.sort_index(inplace=True)

df.rename(columns={'LastName':'SalesPerson'}, inplace=True)

df.head()
# Out:
#                               ProductName    CategoryName  UnitPrice  \
# OrderDate
# 2012-07-04                 Queso Cabrales  Dairy Products       14.0
# 2012-07-04  Singaporean Hokkien Fried Mee  Grains/Cereals        9.8
# 2012-07-04         Mozzarella di Giovanni  Dairy Products       34.8
# 2012-07-05                           Tofu         Produce       18.6
# 2012-07-05          Manjimup Dried Apples         Produce       42.4
#
#             Quantity  Discount                CompanyName ShipCountry  \
# OrderDate
# 2012-07-04        12       0.0  Vins et alcools Chevalier      France
# 2012-07-04        10       0.0  Vins et alcools Chevalier      France
# 2012-07-04         5       0.0  Vins et alcools Chevalier      France
# 2012-07-05         9       0.0         Toms Spezialitäten     Germany
# 2012-07-05        40       0.0         Toms Spezialitäten     Germany
#
#                 ShipRegion  ShipVia SalesPerson
# OrderDate
# 2012-07-04  Western Europe        3    Buchanan
# 2012-07-04  Western Europe        3    Buchanan
# 2012-07-04  Western Europe        3    Buchanan
# 2012-07-05  Western Europe        1      Suyama
# 2012-07-05  Western Europe        1      Suyama

# %%
df['Total'] = df['UnitPrice']*df['Quantity']*(1-df['Discount'])

df['2014':'2015']['Total'].resample('Q').sum().plot()

# %%
df.pivot_table(values='Total', index='ShipRegion',
               aggfunc=sum).sort_values(by='Total',
                ascending=False).style.format('{:.0f}')
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_edfd33cc_e447_11e9_b7a4_5241c6900cf6" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Total</th>
#     </tr>    <tr>
#         <th class="index_name level0" >ShipRegion</th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_edfd33cc_e447_11e9_b7a4_5241c6900cf6level0_row0" class="row_heading level0 row0" >Western Europe</th>
#         <td id="T_edfd33cc_e447_11e9_b7a4_5241c6900cf6row0_col0" class="data row0 col0" >143783825</td>
#     </tr>    <tr>
#         <th id="T_edfd33cc_e447_11e9_b7a4_5241c6900cf6level0_row1" class="row_heading level0 row1" >South America</th>
#         <td id="T_edfd33cc_e447_11e9_b7a4_5241c6900cf6row1_col0" class="data row1 col0" >81826582</td>
#     </tr>    <tr>
#         <th id="T_edfd33cc_e447_11e9_b7a4_5241c6900cf6level0_row2" class="row_heading level0 row2" >North America</th>
#         <td id="T_edfd33cc_e447_11e9_b7a4_5241c6900cf6row2_col0" class="data row2 col0" >80042603</td>
#     </tr>    <tr>
#         <th id="T_edfd33cc_e447_11e9_b7a4_5241c6900cf6level0_row3" class="row_heading level0 row3" >Southern Europe</th>
#         <td id="T_edfd33cc_e447_11e9_b7a4_5241c6900cf6row3_col0" class="data row3 col0" >43369206</td>
#     </tr>    <tr>
#         <th id="T_edfd33cc_e447_11e9_b7a4_5241c6900cf6level0_row4" class="row_heading level0 row4" >British Isles</th>
#         <td id="T_edfd33cc_e447_11e9_b7a4_5241c6900cf6row4_col0" class="data row4 col0" >42054821</td>
#     </tr>    <tr>
#         <th id="T_edfd33cc_e447_11e9_b7a4_5241c6900cf6level0_row5" class="row_heading level0 row5" >Central America</th>
#         <td id="T_edfd33cc_e447_11e9_b7a4_5241c6900cf6row5_col0" class="data row5 col0" >25728089</td>
#     </tr>    <tr>
#         <th id="T_edfd33cc_e447_11e9_b7a4_5241c6900cf6level0_row6" class="row_heading level0 row6" >Northern Europe</th>
#         <td id="T_edfd33cc_e447_11e9_b7a4_5241c6900cf6row6_col0" class="data row6 col0" >20681051</td>
#     </tr>    <tr>
#         <th id="T_edfd33cc_e447_11e9_b7a4_5241c6900cf6level0_row7" class="row_heading level0 row7" >Scandinavia</th>
#         <td id="T_edfd33cc_e447_11e9_b7a4_5241c6900cf6row7_col0" class="data row7 col0" >15468057</td>
#     </tr>    <tr>
#         <th id="T_edfd33cc_e447_11e9_b7a4_5241c6900cf6level0_row8" class="row_heading level0 row8" >Eastern Europe</th>
#         <td id="T_edfd33cc_e447_11e9_b7a4_5241c6900cf6row8_col0" class="data row8 col0" >4874972</td>
#     </tr></tbody>
# </table>

# %%
df['2015'].pivot_table(values='Total', columns='ShipRegion',
                      index='SalesPerson', aggfunc=sum).style.format('{:.0f}')
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_55e933c8_e448_11e9_b942_5241c6900cf6" >
# <thead>    <tr>
#         <th class="index_name level0" >ShipRegion</th>
#         <th class="col_heading level0 col0" >British Isles</th>
#         <th class="col_heading level0 col1" >Central America</th>
#         <th class="col_heading level0 col2" >Eastern Europe</th>
#         <th class="col_heading level0 col3" >North America</th>
#         <th class="col_heading level0 col4" >Northern Europe</th>
#         <th class="col_heading level0 col5" >Scandinavia</th>
#         <th class="col_heading level0 col6" >South America</th>
#         <th class="col_heading level0 col7" >Southern Europe</th>
#         <th class="col_heading level0 col8" >Western Europe</th>
#     </tr>    <tr>
#         <th class="index_name level0" >SalesPerson</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_55e933c8_e448_11e9_b942_5241c6900cf6level0_row0" class="row_heading level0 row0" >Buchanan</th>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row0_col0" class="data row0 col0" >1140139</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row0_col1" class="data row0 col1" >777821</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row0_col2" class="data row0 col2" >87747</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row0_col3" class="data row0 col3" >2580443</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row0_col4" class="data row0 col4" >911757</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row0_col5" class="data row0 col5" >375717</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row0_col6" class="data row0 col6" >2783018</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row0_col7" class="data row0 col7" >781339</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row0_col8" class="data row0 col8" >4217372</td>
#     </tr>    <tr>
#         <th id="T_55e933c8_e448_11e9_b942_5241c6900cf6level0_row1" class="row_heading level0 row1" >Callahan</th>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row1_col0" class="data row1 col0" >1452592</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row1_col1" class="data row1 col1" >647614</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row1_col2" class="data row1 col2" >65154</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row1_col3" class="data row1 col3" >2561733</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row1_col4" class="data row1 col4" >441240</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row1_col5" class="data row1 col5" >310492</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row1_col6" class="data row1 col6" >2559595</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row1_col7" class="data row1 col7" >1072740</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row1_col8" class="data row1 col8" >3997767</td>
#     </tr>    <tr>
#         <th id="T_55e933c8_e448_11e9_b942_5241c6900cf6level0_row2" class="row_heading level0 row2" >Davolio</th>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row2_col0" class="data row2 col0" >1363071</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row2_col1" class="data row2 col1" >812916</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row2_col2" class="data row2 col2" >292521</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row2_col3" class="data row2 col3" >2056418</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row2_col4" class="data row2 col4" >683548</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row2_col5" class="data row2 col5" >587754</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row2_col6" class="data row2 col6" >2606509</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row2_col7" class="data row2 col7" >1143172</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row2_col8" class="data row2 col8" >4362188</td>
#     </tr>    <tr>
#         <th id="T_55e933c8_e448_11e9_b942_5241c6900cf6level0_row3" class="row_heading level0 row3" >Dodsworth</th>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row3_col0" class="data row3 col0" >1161943</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row3_col1" class="data row3 col1" >889162</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row3_col2" class="data row3 col2" >151539</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row3_col3" class="data row3 col3" >1991106</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row3_col4" class="data row3 col4" >573354</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row3_col5" class="data row3 col5" >471887</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row3_col6" class="data row3 col6" >2741282</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row3_col7" class="data row3 col7" >928782</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row3_col8" class="data row3 col8" >4875433</td>
#     </tr>    <tr>
#         <th id="T_55e933c8_e448_11e9_b942_5241c6900cf6level0_row4" class="row_heading level0 row4" >Fuller</th>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row4_col0" class="data row4 col0" >1091760</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row4_col1" class="data row4 col1" >986251</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row4_col2" class="data row4 col2" >138551</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row4_col3" class="data row4 col3" >2650126</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row4_col4" class="data row4 col4" >460450</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row4_col5" class="data row4 col5" >364876</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row4_col6" class="data row4 col6" >3240379</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row4_col7" class="data row4 col7" >1199142</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row4_col8" class="data row4 col8" >4080271</td>
#     </tr>    <tr>
#         <th id="T_55e933c8_e448_11e9_b942_5241c6900cf6level0_row5" class="row_heading level0 row5" >King</th>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row5_col0" class="data row5 col0" >1507273</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row5_col1" class="data row5 col1" >911735</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row5_col2" class="data row5 col2" >141710</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row5_col3" class="data row5 col3" >2184592</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row5_col4" class="data row5 col4" >798335</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row5_col5" class="data row5 col5" >804845</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row5_col6" class="data row5 col6" >2291608</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row5_col7" class="data row5 col7" >1393939</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row5_col8" class="data row5 col8" >4893079</td>
#     </tr>    <tr>
#         <th id="T_55e933c8_e448_11e9_b942_5241c6900cf6level0_row6" class="row_heading level0 row6" >Leverling</th>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row6_col0" class="data row6 col0" >1267842</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row6_col1" class="data row6 col1" >643008</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row6_col2" class="data row6 col2" >41788</td>
#         <td id="T_55e933c8_e448_11e9_b942_5241c6900cf6row6_col3" class="d

# %%
(pd.crosstab(df['SalesPerson'], df['ShipVia'], normalize='index')*100).style.format('{:.1f} %')
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_e9f6c4e4_e448_11e9_88af_5241c6900cf6" >
# <thead>    <tr>
#         <th class="index_name level0" >ShipVia</th>
#         <th class="col_heading level0 col0" >1</th>
#         <th class="col_heading level0 col1" >2</th>
#         <th class="col_heading level0 col2" >3</th>
#     </tr>    <tr>
#         <th class="index_name level0" >SalesPerson</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_e9f6c4e4_e448_11e9_88af_5241c6900cf6level0_row0" class="row_heading level0 row0" >Buchanan</th>
#         <td id="T_e9f6c4e4_e448_11e9_88af_5241c6900cf6row0_col0" class="data row0 col0" >34.2 %</td>
#         <td id="T_e9f6c4e4_e448_11e9_88af_5241c6900cf6row0_col1" class="data row0 col1" >32.6 %</td>
#         <td id="T_e9f6c4e4_e448_11e9_88af_5241c6900cf6row0_col2" class="data row0 col2" >33.2 %</td>
#     </tr>    <tr>
#         <th id="T_e9f6c4e4_e448_11e9_88af_5241c6900cf6level0_row1" class="row_heading level0 row1" >Callahan</th>
#         <td id="T_e9f6c4e4_e448_11e9_88af_5241c6900cf6row1_col0" class="data row1 col0" >29.9 %</td>
#         <td id="T_e9f6c4e4_e448_11e9_88af_5241c6900cf6row1_col1" class="data row1 col1" >36.0 %</td>
#         <td id="T_e9f6c4e4_e448_11e9_88af_5241c6900cf6row1_col2" class="data row1 col2" >34.1 %</td>
#     </tr>    <tr>
#         <th id="T_e9f6c4e4_e448_11e9_88af_5241c6900cf6level0_row2" class="row_heading level0 row2" >Davolio</th>
#         <td id="T_e9f6c4e4_e448_11e9_88af_5241c6900cf6row2_col0" class="data row2 col0" >32.6 %</td>
#         <td id="T_e9f6c4e4_e448_11e9_88af_5241c6900cf6row2_col1" class="data row2 col1" >33.6 %</td>
#         <td id="T_e9f6c4e4_e448_11e9_88af_5241c6900cf6row2_col2" class="data row2 col2" >33.8 %</td>
#     </tr>    <tr>
#         <th id="T_e9f6c4e4_e448_11e9_88af_5241c6900cf6level0_row3" class="row_heading level0 row3" >Dodsworth</th>
#         <td id="T_e9f6c4e4_e448_11e9_88af_5241c6900cf6row3_col0" class="data row3 col0" >34.6 %</td>
#         <td id="T_e9f6c4e4_e448_11e9_88af_5241c6900cf6row3_col1" class="data row3 col1" >32.8 %</td>
#         <td id="T_e9f6c4e4_e448_11e9_88af_5241c6900cf6row3_col2" class="data row3 col2" >32.6 %</td>
#     </tr>    <tr>
#         <th id="T_e9f6c4e4_e448_11e9_88af_5241c6900cf6level0_row4" class="row_heading level0 row4" >Fuller</th>
#         <td id="T_e9f6c4e4_e448_11e9_88af_5241c6900cf6row4_col0" class="data row4 col0" >34.0 %</td>
#         <td id="T_e9f6c4e4_e448_11e9_88af_5241c6900cf6row4_col1" class="data row4 col1" >33.8 %</td>
#         <td id="T_e9f6c4e4_e448_11e9_88af_5241c6900cf6row4_col2" class="data row4 col2" >32.2 %</td>
#     </tr>    <tr>
#         <th id="T_e9f6c4e4_e448_11e9_88af_5241c6900cf6level0_row5" class="row_heading level0 row5" >King</th>
#         <td id="T_e9f6c4e4_e448_11e9_88af_5241c6900cf6row5_col0" class="data row5 col0" >32.1 %</td>
#         <td id="T_e9f6c4e4_e448_11e9_88af_5241c6900cf6row5_col1" class="data row5 col1" >32.7 %</td>
#         <td id="T_e9f6c4e4_e448_11e9_88af_5241c6900cf6row5_col2" class="data row5 col2" >35.2 %</td>
#     </tr>    <tr>
#         <th id="T_e9f6c4e4_e448_11e9_88af_5241c6900cf6level0_row6" class="row_heading level0 row6" >Leverling</th>
#         <td id="T_e9f6c4e4_e448_11e9_88af_5241c6900cf6row6_col0" class="data row6 col0" >34.2 %</td>
#         <td id="T_e9f6c4e4_e448_11e9_88af_5241c6900cf6row6_col1" class="data row6 col1" >30.7 %</td>
#         <td id="T_e9f6c4e4_e448_11e9_88af_5241c6900cf6row6_col2" class="data row6 col2" >35.1 %</td>
#     </tr>    <tr>
#         <th id="T_e9f6c4e4_e448_11e9_88af_5241c6900cf6level0_row7" class="row_heading level0 row7" >Peacock</th>
#         <td id="T_e9f6c4e4_e448_11e9_88af_5241c6900cf6row7_col0" class="data row7 col0" >32.7 %</td>
#         <td id="T_e9f6c4e4_e448_11e9_88af_5241c6900cf6row7_col1" class="data row7 col1" >32.8 %</td>
#         <td id="T_e9f6c4e4_e448_11e9_88af_5241c6900cf6row7_col2" class="data row7 col2" >34.5 %</td>
#     </tr>    <tr>
#         <th id="T_e9f6c4e4_e448_11e9_88af_5241c6900cf6level0_row8" class="row_heading level0 row8" >Suyama</th>
#         <td id="T_e9f6c4e4_e448_11e9_88af_5241c6900cf6row8_col0" class="data row8 col0" >34.8 %</td>
#         <td id="T_e9f6c4e4_e448_11e9_88af_5241c6900cf6row8_col1" class="data row8 col1" >32.6 %</td>
#         <td id="T_e9f6c4e4_e448_11e9_88af_5241c6900cf6row8_col2" class="data row8 col2" >32.6 %</td>
#     </tr></tbody>
# </table>

# %%
import seaborn as sns
sns.heatmap(data=(pd.crosstab(df['SalesPerson'], 
        df['ShipVia'], normalize='index')*100), annot=True)
